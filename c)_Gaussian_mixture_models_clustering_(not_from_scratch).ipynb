# %% [markdown]
# <a href="https://colab.research.google.com/github/ParsaKeerthana/Clustering-Assignment/blob/main/c)_Gaussian_mixture_models_clustering_(not_from_scratch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

# Generate synthetic data
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Preprocess the data (optional, depending on your dataset)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create GMM model
n_components = 4  # This can be varied based on your data and requirement
gmm = GaussianMixture(n_components=n_components, random_state=0)

# Fit the model
gmm.fit(X_scaled)

# Predict cluster labels
labels = gmm.predict(X_scaled)

# Plotting the results
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, s=40, cmap='viridis')
plt.title("Gaussian Mixture Model Clustering")
plt.show()
